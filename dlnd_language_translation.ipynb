# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source_id = [[source_vocab_to_int[word] for word in sentence.split(' ') if word != '']\
                 for sentence in source_text.split('\n')]

    target_id = [[target_vocab_to_int[word] for word in sentence.split(' ') + ['<EOS>'] if word != '']\
                 for sentence in target_text.split('\n')]
    
    return source_id, target_id

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.3.0
# C:\Program Files\Anaconda3\envs\dlnd-tf-lab\lib\site-packages\ipykernel\__main__.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs = tf.placeholder(tf.int32, shape=[None, None], name='input')
    targets = tf.placeholder(tf.int32, shape=[None, None])
    learning_rate = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32, shape=[None], name='target_sequence_length')
    max_target_len = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, shape=[None], name='source_sequence_length')
    
    return inputs, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\__main__.py", line 3, in <module>\n    app.launch_new_instance()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\traitlets\\config\\application.py", line 658, in launch_instance\n    app.start()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelapp.py", line 474, in start\n    ioloop.IOLoop.instance().start()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tornado\\ioloop.py", line 887, in start\n    handler_func(fd_obj, events)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tornado\\stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tornado\\stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelbase.py", line 276, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelbase.py", line 228, in dispatch_shell\n    handler(stream, idents, msg)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelbase.py", line 390, in execute_request\n    user_expressions, allow_stdin)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\zmqshell.py", line 501, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2717, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2827, in run_ast_nodes\n    if self.run_code(code, result):', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2881, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-7-0fa51df0373e>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "C:\\Users\\idmanaog\\Documents\\iadm_HP840_G1\\Udacity\\DeepLearning\\Proj4_Language-Translation\\SimilarSolution\\language-translation-master\\problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tensorflow\\python\\ops\\check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib ...
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\__main__.py", line 3, in <module>\n    app.launch_new_instance()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\traitlets\\config\\application.py", line 658, in launch_instance\n    app.start()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelapp.py", line 474, in start\n    ioloop.IOLoop.instance().start()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tornado\\ioloop.py", line 887, in start\n    handler_func(fd_obj, events)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tornado\\stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\zmq\\eventloop\\zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tornado\\stack_context.py", line 275, in null_wrapper\n    return fn(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelbase.py", line 276, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelbase.py", line 228, in dispatch_shell\n    handler(stream, idents, msg)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\kernelbase.py", line 390, in execute_request\n    user_expressions, allow_stdin)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\ipykernel\\zmqshell.py", line 501, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2717, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2827, in run_ast_nodes\n    if self.run_code(code, result):', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\IPython\\core\\interactiveshell.py", line 2881, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-7-0fa51df0373e>", line 21, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "C:\\Users\\idmanaog\\Documents\\iadm_HP840_G1\\Udacity\\DeepLearning\\Proj4_Language-Translation\\SimilarSolution\\language-translation-master\\problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-tf-lab\\lib\\site-packages\\tensorflow\\python\\ops\\check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "C:\\Program Files\\Anaconda3\\envs\\dlnd-t ...
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    first_elements = tf.fill([batch_size, 1], target_vocab_to_int['<GO>'])
    target_data = tf.concat([first_elements, target_data], axis=1)
    target_data = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1,1])
    return target_data


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    embedding = tf.contrib.layers.embed_sequence(rnn_inputs,
                                                 vocab_size=source_vocab_size,
                                                 embed_dim=encoding_embedding_size)
    
    lstm_cell = lambda size: tf.contrib.rnn.LSTMCell(size)

    stack = tf.contrib.rnn.MultiRNNCell([lstm_cell(rnn_size) for _ in range(num_layers)])
    drop = tf.contrib.rnn.DropoutWrapper(stack, input_keep_prob=keep_prob)
    
    return tf.nn.dynamic_rnn(drop, embedding, dtype=embedding.dtype)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    training_helper = tf.contrib.seq2seq.TrainingHelper(dec_embed_input, target_sequence_length)
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, training_helper, encoder_state, output_layer)
    outputs, *_ = tf.contrib.seq2seq.dynamic_decode(decoder)
    return outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    embed_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                            batch_size * [start_of_sequence_id],
                                                            end_of_sequence_id)
    decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell, embed_helper, encoder_state, output_layer)
    outputs, *_ = tf.contrib.seq2seq.dynamic_decode(decoder,
                                                    impute_finished=True, 
                                                    maximum_iterations=max_target_sequence_length)
    return outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    lstm_cell = lambda size: tf.contrib.rnn.LSTMCell(size)
    stack = tf.contrib.rnn.MultiRNNCell([lstm_cell(rnn_size) for _ in range(num_layers)])
    dec_cell = tf.contrib.rnn.DropoutWrapper(stack, input_keep_prob=keep_prob)
       
    with tf.variable_scope('decoding') as scope:
        output_layer = Dense(target_vocab_size, name='output_layer')
        dec_train = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                                         target_sequence_length, max_target_sequence_length, 
                                         output_layer, keep_prob)
        scope.reuse_variables()
        dec_infer = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, target_vocab_to_int['<GO>'],
                                         target_vocab_to_int['<EOS>'], max_target_sequence_length,
                                         target_vocab_size, output_layer, batch_size, keep_prob)
        
    return dec_train, dec_infer



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    encoder_output, encoder_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                                                   source_sequence_length, source_vocab_size, 
                                                   enc_embedding_size)
    decoder_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    decoder_output = decoding_layer(decoder_input, encoder_state, target_sequence_length, 
                                    max_target_sentence_length, rnn_size, num_layers, 
                                    target_vocab_to_int, target_vocab_size, batch_size, keep_prob, 
                                    dec_embedding_size)
    
    return decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
##epochs = 10
epochs = 8  # As suggested by the grader on 9/18/17
# Batch Size
batch_size = 128
# RNN Size
##rnn_size = 64
rnn_size = 128  # As suggested by the grader on 9/18/17
# Number of Layers
## num_layers = 3
num_layers = 2 # As suggested by the grader on 9/18/17
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5
display_step = 16

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   16/1077 - Train Accuracy: 0.3383, Validation Accuracy: 0.3839, Loss: 3.0779
# Epoch   0 Batch   32/1077 - Train Accuracy: 0.4442, Validation Accuracy: 0.4542, Loss: 2.4626
# Epoch   0 Batch   48/1077 - Train Accuracy: 0.4375, Validation Accuracy: 0.4798, Loss: 2.3209
# Epoch   0 Batch   64/1077 - Train Accuracy: 0.4578, Validation Accuracy: 0.5217, Loss: 2.1559
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.5047, Validation Accuracy: 0.5455, Loss: 1.9138
# Epoch   0 Batch   96/1077 - Train Accuracy: 0.5184, Validation Accuracy: 0.5518, Loss: 1.6382
# Epoch   0 Batch  112/1077 - Train Accuracy: 0.5227, Validation Accuracy: 0.5565, Loss: 1.4289
# Epoch   0 Batch  128/1077 - Train Accuracy: 0.5632, Validation Accuracy: 0.5668, Loss: 1.1376
# Epoch   0 Batch  144/1077 - Train Accuracy: 0.4984, Validation Accuracy: 0.5739, Loss: 1.0934
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.5578, Validation Accuracy: 0.5707, Loss: 0.8885
# Epoch   0 Batch  176/1077 - Train Accuracy: 0.5523, Validation Accuracy: 0.5788, Loss: 0.8309
# Epoch   0 Batch  192/1077 - Train Accuracy: 0.5852, Validation Accuracy: 0.5920, Loss: 0.7706
# Epoch   0 Batch  208/1077 - Train Accuracy: 0.5908, Validation Accuracy: 0.5817, Loss: 0.7043
# Epoch   0 Batch  224/1077 - Train Accuracy: 0.6258, Validation Accuracy: 0.6076, Loss: 0.6791
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.6520, Validation Accuracy: 0.5977, Loss: 0.6284
# Epoch   0 Batch  256/1077 - Train Accuracy: 0.6016, Validation Accuracy: 0.5955, Loss: 0.6680
# Epoch   0 Batch  272/1077 - Train Accuracy: 0.6432, Validation Accuracy: 0.6190, Loss: 0.6130
# Epoch   0 Batch  288/1077 - Train Accuracy: 0.5969, Validation Accuracy: 0.6250, Loss: 0.6036
# Epoch   0 Batch  304/1077 - Train Accuracy: 0.6551, Validation Accuracy: 0.6353, Loss: 0.5150
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.6586, Validation Accuracy: 0.6264, Loss: 0.5229
# Epoch   0 Batch  336/1077 - Train Accuracy: 0.6609, Validation Accuracy: 0.6641, Loss: 0.5296
# Epoch   0 Batch  352/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.6822, Loss: 0.5026
# Epoch   0 Batch  368/1077 - Train Accuracy: 0.7254, Validation Accuracy: 0.6804, Loss: 0.4838
# Epoch   0 Batch  384/1077 - Train Accuracy: 0.7109, Validation Accuracy: 0.6811, Loss: 0.4555
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.7113, Validation Accuracy: 0.6694, Loss: 0.4629
# Epoch   0 Batch  416/1077 - Train Accuracy: 0.7344, Validation Accuracy: 0.6964, Loss: 0.4394
# Epoch   0 Batch  432/1077 - Train Accuracy: 0.7582, Validation Accuracy: 0.7390, Loss: 0.4132
# Epoch   0 Batch  448/1077 - Train Accuracy: 0.7270, Validation Accuracy: 0.7212, Loss: 0.4024
# Epoch   0 Batch  464/1077 - Train Accuracy: 0.7551, Validation Accuracy: 0.7411, Loss: 0.3654
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.7780, Validation Accuracy: 0.7614, Loss: 0.3602
# Epoch   0 Batch  496/1077 - Train Accuracy: 0.7770, Validation Accuracy: 0.7493, Loss: 0.3535
# Epoch   0 Batch  512/1077 - Train Accuracy: 0.8180, Validation Accuracy: 0.7560, Loss: 0.3087
# Epoch   0 Batch  528/1077 - Train Accuracy: 0.7867, Validation Accuracy: 0.7663, Loss: 0.3101
# Epoch   0 Batch  544/1077 - Train Accuracy: 0.8152, Validation Accuracy: 0.7816, Loss: 0.2772
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.7535, Validation Accuracy: 0.7763, Loss: 0.2949
# Epoch   0 Batch  576/1077 - Train Accuracy: 0.8104, Validation Accuracy: 0.7983, Loss: 0.2823
# Epoch   0 Batch  592/1077 - Train Accuracy: 0.8340, Validation Accuracy: 0.8043, Loss: 0.2716
# Epoch   0 Batch  608/1077 - Train Accuracy: 0.7977, Validation Accuracy: 0.8079, Loss: 0.2616
# Epoch   0 Batch  624/1077 - Train Accuracy: 0.8344, Validation Accuracy: 0.8132, Loss: 0.2425
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.8378, Validation Accuracy: 0.8224, Loss: 0.2301
# Epoch   0 Batch  656/1077 - Train Accuracy: 0.8273, Validation Accuracy: 0.8107, Loss: 0.2357
# Epoch   0 Batch  672/1077 - Train Accuracy: 0.8274, Validation Accuracy: 0.8171, Loss: 0.2044
# Epoch   0 Batch  688/1077 - Train Accuracy: 0.8609, Validation Accuracy: 0.8292, Loss: 0.2072
# Epoch   0 Batch  704/1077 - Train Accuracy: 0.8203, Validation Accuracy: 0.8338, Loss: 0.2267
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.8261, Validation Accuracy: 0.8675, Loss: 0.2082
# Epoch   0 Batch  736/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8374, Loss: 0.1784
# Epoch   0 Batch  752/1077 - Train Accuracy: 0.8397, Validation Accuracy: 0.8363, Loss: 0.1717
# Epoch   0 Batch  768/1077 - Train Accuracy: 0.8441, Validation Accuracy: 0.8263, Loss: 0.1844
# Epoch   0 Batch  784/1077 - Train Accuracy: 0.8648, Validation Accuracy: 0.8569, Loss: 0.1670
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.8453, Validation Accuracy: 0.8569, Loss: 0.1812
# Epoch   0 Batch  816/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8530, Loss: 0.1813
# Epoch   0 Batch  832/1077 - Train Accuracy: 0.8629, Validation Accuracy: 0.8633, Loss: 0.1482
# Epoch   0 Batch  848/1077 - Train Accuracy: 0.8898, Validation Accuracy: 0.8778, Loss: 0.1519
# Epoch   0 Batch  864/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.8583, Loss: 0.1461
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8469, Loss: 0.1416
# Epoch   0 Batch  896/1077 - Train Accuracy: 0.8816, Validation Accuracy: 0.8931, Loss: 0.1553
# Epoch   0 Batch  912/1077 - Train Accuracy: 0.8848, Validation Accuracy: 0.8654, Loss: 0.1411
# Epoch   0 Batch  928/1077 - Train Accuracy: 0.8617, Validation Accuracy: 0.8466, Loss: 0.1318
# Epoch   0 Batch  944/1077 - Train Accuracy: 0.8657, Validation Accuracy: 0.8580, Loss: 0.1216
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.8943, Validation Accuracy: 0.8700, Loss: 0.1196
# Epoch   0 Batch  976/1077 - Train Accuracy: 0.8898, Validation Accuracy: 0.8366, Loss: 0.1165
# Epoch   0 Batch  992/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8931, Loss: 0.1172
# Epoch   0 Batch 1008/1077 - Train Accuracy: 0.8980, Validation Accuracy: 0.8960, Loss: 0.1247
# Epoch   0 Batch 1024/1077 - Train Accuracy: 0.8539, Validation Accuracy: 0.9013, Loss: 0.1308
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.8783, Validation Accuracy: 0.8746, Loss: 0.1201
# Epoch   0 Batch 1056/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8928, Loss: 0.1002
# Epoch   0 Batch 1072/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.8665, Loss: 0.0977
# Epoch   1 Batch   16/1077 - Train Accuracy: 0.8684, Validation Accuracy: 0.8608, Loss: 0.1109
# Epoch   1 Batch   32/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8764, Loss: 0.1010
# Epoch   1 Batch   48/1077 - Train Accuracy: 0.8793, Validation Accuracy: 0.8995, Loss: 0.1243
# Epoch   1 Batch   64/1077 - Train Accuracy: 0.9176, Validation Accuracy: 0.8821, Loss: 0.0860
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.8991, Loss: 0.0914
# Epoch   1 Batch   96/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8924, Loss: 0.0916
# Epoch   1 Batch  112/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.9013, Loss: 0.0850
# Epoch   1 Batch  128/1077 - Train Accuracy: 0.9323, Validation Accuracy: 0.8743, Loss: 0.0850
# Epoch   1 Batch  144/1077 - Train Accuracy: 0.8857, Validation Accuracy: 0.9165, Loss: 0.1097
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8910, Loss: 0.0691
# Epoch   1 Batch  176/1077 - Train Accuracy: 0.8984, Validation Accuracy: 0.9027, Loss: 0.0829
# Epoch   1 Batch  192/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8910, Loss: 0.0825
# Epoch   1 Batch  208/1077 - Train Accuracy: 0.9241, Validation Accuracy: 0.8935, Loss: 0.0786
# Epoch   1 Batch  224/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8910, Loss: 0.0795
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.8853, Loss: 0.0642
# Epoch   1 Batch  256/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.8899, Loss: 0.0990
# Epoch   1 Batch  272/1077 - Train Accuracy: 0.9118, Validation Accuracy: 0.8931, Loss: 0.1023
# Epoch   1 Batch  288/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.9137, Loss: 0.0789
# Epoch   1 Batch  304/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.8725, Loss: 0.0753
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9158, Loss: 0.0769
# Epoch   1 Batch  336/1077 - Train Accuracy: 0.9008, Validation Accuracy: 0.9070, Loss: 0.0912
# Epoch   1 Batch  352/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.9045, Loss: 0.0722
# Epoch   1 Batch  368/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9070, Loss: 0.0701
# Epoch   1 Batch  384/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9098, Loss: 0.0649
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.9055, Loss: 0.0767
# Epoch   1 Batch  416/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.8967, Loss: 0.0711
# Epoch   1 Batch  432/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8960, Loss: 0.0689
# Epoch   1 Batch  448/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9038, Loss: 0.0750
# Epoch   1 Batch  464/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9070, Loss: 0.0603
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.8974, Loss: 0.0566
# Epoch   1 Batch  496/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8903, Loss: 0.0738
# Epoch   1 Batch  512/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9247, Loss: 0.0547
# Epoch   1 Batch  528/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.9112, Loss: 0.0619
# Epoch   1 Batch  544/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.8967, Loss: 0.0479
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.9009, Loss: 0.0553
# Epoch   1 Batch  576/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9087, Loss: 0.0566
# Epoch   1 Batch  592/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.8910, Loss: 0.0550
# Epoch   1 Batch  608/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9059, Loss: 0.0606
# Epoch   1 Batch  624/1077 - Train Accuracy: 0.9111, Validation Accuracy: 0.9062, Loss: 0.0656
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.9200, Validation Accuracy: 0.9165, Loss: 0.0625
# Epoch   1 Batch  656/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9215, Loss: 0.0557
# Epoch   1 Batch  672/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9112, Loss: 0.0464
# Epoch   1 Batch  688/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9048, Loss: 0.0563
# Epoch   1 Batch  704/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9208, Loss: 0.0656
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9254, Loss: 0.0580
# Epoch   1 Batch  736/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.9034, Loss: 0.0440
# Epoch   1 Batch  752/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.9276, Loss: 0.0491
# Epoch   1 Batch  768/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9237, Loss: 0.0484
# Epoch   1 Batch  784/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9276, Loss: 0.0419
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9215, Loss: 0.0551
# Epoch   1 Batch  816/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9201, Loss: 0.0604
# Epoch   1 Batch  832/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9048, Loss: 0.0484
# Epoch   1 Batch  848/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9116, Loss: 0.0491
# Epoch   1 Batch  864/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.9176, Loss: 0.0562
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9201, Loss: 0.0520
# Epoch   1 Batch  896/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9201, Loss: 0.0465
# Epoch   1 Batch  912/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9194, Loss: 0.0469
# Epoch   1 Batch  928/1077 - Train Accuracy: 0.9090, Validation Accuracy: 0.9048, Loss: 0.0524
# Epoch   1 Batch  944/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.9116, Loss: 0.0481
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.9423, Validation Accuracy: 0.9308, Loss: 0.0426
# Epoch   1 Batch  976/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9187, Loss: 0.0443
# Epoch   1 Batch  992/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9134, Loss: 0.0510
# Epoch   1 Batch 1008/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9222, Loss: 0.0525
# Epoch   1 Batch 1024/1077 - Train Accuracy: 0.9164, Validation Accuracy: 0.9194, Loss: 0.0687
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.9350, Validation Accuracy: 0.8991, Loss: 0.0626
# Epoch   1 Batch 1056/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9268, Loss: 0.0430
# Epoch   1 Batch 1072/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9176, Loss: 0.0486
# Epoch   2 Batch   16/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.9286, Loss: 0.0596
# Epoch   2 Batch   32/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9329, Loss: 0.0445
# Epoch   2 Batch   48/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9560, Loss: 0.0683
# Epoch   2 Batch   64/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9272, Loss: 0.0353
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9176, Loss: 0.0503
# Epoch   2 Batch   96/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9222, Loss: 0.0496
# Epoch   2 Batch  112/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9123, Loss: 0.0383
# Epoch   2 Batch  128/1077 - Train Accuracy: 0.9554, Validation Accuracy: 0.9222, Loss: 0.0507
# Epoch   2 Batch  144/1077 - Train Accuracy: 0.9116, Validation Accuracy: 0.9158, Loss: 0.0697
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9364, Loss: 0.0350
# Epoch   2 Batch  176/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9339, Loss: 0.0413
# Epoch   2 Batch  192/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.9062, Loss: 0.0458
# Epoch   2 Batch  208/1077 - Train Accuracy: 0.9386, Validation Accuracy: 0.8991, Loss: 0.0418
# Epoch   2 Batch  224/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9205, Loss: 0.0439
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9187, Loss: 0.0357
# Epoch   2 Batch  256/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.9109, Loss: 0.0640
# Epoch   2 Batch  272/1077 - Train Accuracy: 0.9446, Validation Accuracy: 0.9087, Loss: 0.0651
# Epoch   2 Batch  288/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9247, Loss: 0.0475
# Epoch   2 Batch  304/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8977, Loss: 0.0511
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9339, Loss: 0.0513
# Epoch   2 Batch  336/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9006, Loss: 0.0638
# Epoch   2 Batch  352/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9183, Loss: 0.0458
# Epoch   2 Batch  368/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9240, Loss: 0.0410
# Epoch   2 Batch  384/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9467, Loss: 0.0365
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9304, Loss: 0.0505
# Epoch   2 Batch  416/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9290, Loss: 0.0426
# Epoch   2 Batch  432/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9318, Loss: 0.0449
# Epoch   2 Batch  448/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9212, Loss: 0.0532
# Epoch   2 Batch  464/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9144, Loss: 0.0448
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.8995, Loss: 0.0480
# Epoch   2 Batch  496/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9322, Loss: 0.0461
# Epoch   2 Batch  512/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9293, Loss: 0.0398
# Epoch   2 Batch  528/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9183, Loss: 0.0357
# Epoch   2 Batch  544/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9077, Loss: 0.0292
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9205, Loss: 0.0465
# Epoch   2 Batch  576/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9187, Loss: 0.0400
# Epoch   2 Batch  592/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9279, Loss: 0.0450
# Epoch   2 Batch  608/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.8995, Loss: 0.0479
# Epoch   2 Batch  624/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9293, Loss: 0.0484
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.9368, Loss: 0.0414
# Epoch   2 Batch  656/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9226, Loss: 0.0442
# Epoch   2 Batch  672/1077 - Train Accuracy: 0.9475, Validation Accuracy: 0.9382, Loss: 0.0368
# Epoch   2 Batch  688/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9435, Loss: 0.0352
# Epoch   2 Batch  704/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9339, Loss: 0.0457
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9411, Loss: 0.0433
# Epoch   2 Batch  736/1077 - Train Accuracy: 0.9428, Validation Accuracy: 0.9134, Loss: 0.0408
# Epoch   2 Batch  752/1077 - Train Accuracy: 0.9304, Validation Accuracy: 0.9261, Loss: 0.0354
# Epoch   2 Batch  768/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9386, Loss: 0.0383
# Epoch   2 Batch  784/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9105, Loss: 0.0284
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9233, Loss: 0.0449
# Epoch   2 Batch  816/1077 - Train Accuracy: 0.9650, Validation Accuracy: 0.9411, Loss: 0.0419
# Epoch   2 Batch  832/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9304, Loss: 0.0361
# Epoch   2 Batch  848/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9276, Loss: 0.0312
# Epoch   2 Batch  864/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9251, Loss: 0.0422
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9308, Loss: 0.0440
# Epoch   2 Batch  896/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9329, Loss: 0.0435
# Epoch   2 Batch  912/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9031, Loss: 0.0408
# Epoch   2 Batch  928/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9251, Loss: 0.0391
# Epoch   2 Batch  944/1077 - Train Accuracy: 0.9438, Validation Accuracy: 0.9283, Loss: 0.0401
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9420, Validation Accuracy: 0.9393, Loss: 0.0334
# Epoch   2 Batch  976/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9325, Loss: 0.0321
# Epoch   2 Batch  992/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9361, Loss: 0.0382
# Epoch   2 Batch 1008/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9254, Loss: 0.0527
# Epoch   2 Batch 1024/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9261, Loss: 0.0631
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9256, Validation Accuracy: 0.9343, Loss: 0.0553
# Epoch   2 Batch 1056/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9467, Loss: 0.0346
# Epoch   2 Batch 1072/1077 - Train Accuracy: 0.9468, Validation Accuracy: 0.9343, Loss: 0.0399
# Epoch   3 Batch   16/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9251, Loss: 0.0425
# Epoch   3 Batch   32/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.9371, Loss: 0.0424
# Epoch   3 Batch   48/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9251, Loss: 0.0597
# Epoch   3 Batch   64/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9197, Loss: 0.0328
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9276, Loss: 0.0498
# Epoch   3 Batch   96/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9343, Loss: 0.0449
# Epoch   3 Batch  112/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.8963, Loss: 0.0284
# Epoch   3 Batch  128/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9254, Loss: 0.0381
# Epoch   3 Batch  144/1077 - Train Accuracy: 0.9248, Validation Accuracy: 0.9357, Loss: 0.0620
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9464, Loss: 0.0281
# Epoch   3 Batch  176/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9286, Loss: 0.0456
# Epoch   3 Batch  192/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9261, Loss: 0.0540
# Epoch   3 Batch  208/1077 - Train Accuracy: 0.9327, Validation Accuracy: 0.9194, Loss: 0.0450
# Epoch   3 Batch  224/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9300, Loss: 0.0381
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9382, Loss: 0.0388
# Epoch   3 Batch  256/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.9492, Loss: 0.0639
# Epoch   3 Batch  272/1077 - Train Accuracy: 0.9546, Validation Accuracy: 0.9379, Loss: 0.0614
# Epoch   3 Batch  288/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9418, Loss: 0.0455
# Epoch   3 Batch  304/1077 - Train Accuracy: 0.9330, Validation Accuracy: 0.9215, Loss: 0.0473
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9585, Loss: 0.0525
# Epoch   3 Batch  336/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9361, Loss: 0.0542
# Epoch   3 Batch  352/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9293, Loss: 0.0343
# Epoch   3 Batch  368/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9364, Loss: 0.0361
# Epoch   3 Batch  384/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9531, Loss: 0.0401
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9382, Loss: 0.0422
# Epoch   3 Batch  416/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9325, Loss: 0.0369
# Epoch   3 Batch  432/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9371, Loss: 0.0432
# Epoch   3 Batch  448/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9205, Loss: 0.0460
# Epoch   3 Batch  464/1077 - Train Accuracy: 0.9645, Validation Accuracy: 0.9212, Loss: 0.0325
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9489, Loss: 0.0357
# Epoch   3 Batch  496/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9496, Loss: 0.0398
# Epoch   3 Batch  512/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9396, Loss: 0.0339
# Epoch   3 Batch  528/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.9265, Loss: 0.0448
# Epoch   3 Batch  544/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9183, Loss: 0.0344
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9141, Loss: 0.0377
# Epoch   3 Batch  576/1077 - Train Accuracy: 0.9700, Validation Accuracy: 0.9453, Loss: 0.0353
# Epoch   3 Batch  592/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9542, Loss: 0.0414
# Epoch   3 Batch  608/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9382, Loss: 0.0427
# Epoch   3 Batch  624/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9361, Loss: 0.0396
# Epoch   3 Batch  640/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9403, Loss: 0.0342
# Epoch   3 Batch  656/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9393, Loss: 0.0397
# Epoch   3 Batch  672/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9361, Loss: 0.0343
# Epoch   3 Batch  688/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9389, Loss: 0.0378
# Epoch   3 Batch  704/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9545, Loss: 0.0555
# Epoch   3 Batch  720/1077 - Train Accuracy: 0.9581, Validation Accuracy: 0.9414, Loss: 0.0372
# Epoch   3 Batch  736/1077 - Train Accuracy: 0.9646, Validation Accuracy: 0.9453, Loss: 0.0344
# Epoch   3 Batch  752/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9510, Loss: 0.0331
# Epoch   3 Batch  768/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9396, Loss: 0.0386
# Epoch   3 Batch  784/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9538, Loss: 0.0275
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9428, Loss: 0.0402
# Epoch   3 Batch  816/1077 - Train Accuracy: 0.9515, Validation Accuracy: 0.9396, Loss: 0.0401
# Epoch   3 Batch  832/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9389, Loss: 0.0368
# Epoch   3 Batch  848/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9510, Loss: 0.0302
# Epoch   3 Batch  864/1077 - Train Accuracy: 0.9168, Validation Accuracy: 0.9396, Loss: 0.0369
# Epoch   3 Batch  880/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9403, Loss: 0.0328
# Epoch   3 Batch  896/1077 - Train Accuracy: 0.9424, Validation Accuracy: 0.9339, Loss: 0.0405
# Epoch   3 Batch  912/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9396, Loss: 0.0364
# Epoch   3 Batch  928/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9425, Loss: 0.0410
# Epoch   3 Batch  944/1077 - Train Accuracy: 0.9338, Validation Accuracy: 0.9513, Loss: 0.0365
# Epoch   3 Batch  960/1077 - Train Accuracy: 0.9583, Validation Accuracy: 0.9414, Loss: 0.0301
# Epoch   3 Batch  976/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9467, Loss: 0.0312
# Epoch   3 Batch  992/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9201, Loss: 0.0476
# Epoch   3 Batch 1008/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9407, Loss: 0.0490
# Epoch   3 Batch 1024/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.9478, Loss: 0.0550
# Epoch   3 Batch 1040/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9432, Loss: 0.0453
# Epoch   3 Batch 1056/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9538, Loss: 0.0368
# Epoch   3 Batch 1072/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9496, Loss: 0.0289
# Epoch   4 Batch   16/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9268, Loss: 0.0448
# Epoch   4 Batch   32/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9489, Loss: 0.0399
# Epoch   4 Batch   48/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9482, Loss: 0.0634
# Epoch   4 Batch   64/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9297, Loss: 0.0293
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.9304, Loss: 0.0380
# Epoch   4 Batch   96/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9432, Loss: 0.0419
# Epoch   4 Batch  112/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9439, Loss: 0.0332
# Epoch   4 Batch  128/1077 - Train Accuracy: 0.9781, Validation Accuracy: 0.9304, Loss: 0.0350
# Epoch   4 Batch  144/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9052, Loss: 0.0612
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9265, Loss: 0.0322
# Epoch   4 Batch  176/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9254, Loss: 0.0375
# Epoch   4 Batch  192/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9400, Loss: 0.0485
# Epoch   4 Batch  208/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9077, Loss: 0.0378
# Epoch   4 Batch  224/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9304, Loss: 0.0423
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9762, Validation Accuracy: 0.9439, Loss: 0.0320
# Epoch   4 Batch  256/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.9194, Loss: 0.0522
# Epoch   4 Batch  272/1077 - Train Accuracy: 0.9423, Validation Accuracy: 0.9357, Loss: 0.0516
# Epoch   4 Batch  288/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9478, Loss: 0.0464
# Epoch   4 Batch  304/1077 - Train Accuracy: 0.9401, Validation Accuracy: 0.9091, Loss: 0.0410
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9531, Loss: 0.0496
# Epoch   4 Batch  336/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.9315, Loss: 0.0585
# Epoch   4 Batch  352/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9229, Loss: 0.0491
# Epoch   4 Batch  368/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9382, Loss: 0.0366
# Epoch   4 Batch  384/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9421, Loss: 0.0340
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9503, Loss: 0.0452
# Epoch   4 Batch  416/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9489, Loss: 0.0386
# Epoch   4 Batch  432/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9343, Loss: 0.0378
# Epoch   4 Batch  448/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9286, Loss: 0.0440
# Epoch   4 Batch  464/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9428, Loss: 0.0339
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9618, Validation Accuracy: 0.9293, Loss: 0.0317
# Epoch   4 Batch  496/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9428, Loss: 0.0345
# Epoch   4 Batch  512/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9513, Loss: 0.0356
# Epoch   4 Batch  528/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.9482, Loss: 0.0362
# Epoch   4 Batch  544/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9364, Loss: 0.0224
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9276, Loss: 0.0354
# Epoch   4 Batch  576/1077 - Train Accuracy: 0.9428, Validation Accuracy: 0.9336, Loss: 0.0327
# Epoch   4 Batch  592/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9173, Loss: 0.0392
# Epoch   4 Batch  608/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9268, Loss: 0.0460
# Epoch   4 Batch  624/1077 - Train Accuracy: 0.9479, Validation Accuracy: 0.9535, Loss: 0.0392
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9517, Loss: 0.0348
# Epoch   4 Batch  656/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9361, Loss: 0.0406
# Epoch   4 Batch  672/1077 - Train Accuracy: 0.9528, Validation Accuracy: 0.9311, Loss: 0.0334
# Epoch   4 Batch  688/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9357, Loss: 0.0304
# Epoch   4 Batch  704/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9315, Loss: 0.0415
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.9470, Validation Accuracy: 0.9521, Loss: 0.0308
# Epoch   4 Batch  736/1077 - Train Accuracy: 0.9502, Validation Accuracy: 0.9371, Loss: 0.0394
# Epoch   4 Batch  752/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9513, Loss: 0.0294
# Epoch   4 Batch  768/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9460, Loss: 0.0324
# Epoch   4 Batch  784/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9556, Loss: 0.0268
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9382, Loss: 0.0390
# Epoch   4 Batch  816/1077 - Train Accuracy: 0.9642, Validation Accuracy: 0.9304, Loss: 0.0422
# Epoch   4 Batch  832/1077 - Train Accuracy: 0.9543, Validation Accuracy: 0.9308, Loss: 0.0268
# Epoch   4 Batch  848/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9418, Loss: 0.0410
# Epoch   4 Batch  864/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9265, Loss: 0.0336
# Epoch   4 Batch  880/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9258, Loss: 0.0326
# Epoch   4 Batch  896/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9624, Loss: 0.0358
# Epoch   4 Batch  912/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.9375, Loss: 0.0399
# Epoch   4 Batch  928/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9478, Loss: 0.0315
# Epoch   4 Batch  944/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9538, Loss: 0.0333
# Epoch   4 Batch  960/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9325, Loss: 0.0368
# Epoch   4 Batch  976/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9439, Loss: 0.0301
# Epoch   4 Batch  992/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9386, Loss: 0.0472
# Epoch   4 Batch 1008/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9371, Loss: 0.0452
# Epoch   4 Batch 1024/1077 - Train Accuracy: 0.9336, Validation Accuracy: 0.9354, Loss: 0.0451
# Epoch   4 Batch 1040/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9297, Loss: 0.0468
# Epoch   4 Batch 1056/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9411, Loss: 0.0311
# Epoch   4 Batch 1072/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9549, Loss: 0.0315
# Epoch   5 Batch   16/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9528, Loss: 0.0400
# Epoch   5 Batch   32/1077 - Train Accuracy: 0.9542, Validation Accuracy: 0.9485, Loss: 0.0323
# Epoch   5 Batch   48/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9379, Loss: 0.0605
# Epoch   5 Batch   64/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9517, Loss: 0.0311
# Epoch   5 Batch   80/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9531, Loss: 0.0312
# Epoch   5 Batch   96/1077 - Train Accuracy: 0.9238, Validation Accuracy: 0.9485, Loss: 0.0403
# Epoch   5 Batch  112/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9403, Loss: 0.0261
# Epoch   5 Batch  128/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9304, Loss: 0.0427
# Epoch   5 Batch  144/1077 - Train Accuracy: 0.9276, Validation Accuracy: 0.9237, Loss: 0.0530
# Epoch   5 Batch  160/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9474, Loss: 0.0304
# Epoch   5 Batch  176/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.9375, Loss: 0.0389
# Epoch   5 Batch  192/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9279, Loss: 0.0466
# Epoch   5 Batch  208/1077 - Train Accuracy: 0.9639, Validation Accuracy: 0.9379, Loss: 0.0311
# Epoch   5 Batch  224/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9350, Loss: 0.0402
# Epoch   5 Batch  240/1077 - Train Accuracy: 0.9801, Validation Accuracy: 0.9343, Loss: 0.0249
# Epoch   5 Batch  256/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9425, Loss: 0.0531
# Epoch   5 Batch  272/1077 - Train Accuracy: 0.9345, Validation Accuracy: 0.9435, Loss: 0.0523
# Epoch   5 Batch  288/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9485, Loss: 0.0389
# Epoch   5 Batch  304/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9126, Loss: 0.0357
# Epoch   5 Batch  320/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9389, Loss: 0.0479
# Epoch   5 Batch  336/1077 - Train Accuracy: 0.9340, Validation Accuracy: 0.9244, Loss: 0.0503
# Epoch   5 Batch  352/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9158, Loss: 0.0331
# Epoch   5 Batch  368/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9315, Loss: 0.0400
# Epoch   5 Batch  384/1077 - Train Accuracy: 0.9711, Validation Accuracy: 0.9318, Loss: 0.0326
# Epoch   5 Batch  400/1077 - Train Accuracy: 0.9352, Validation Accuracy: 0.9517, Loss: 0.0431
# Epoch   5 Batch  416/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9574, Loss: 0.0364
# Epoch   5 Batch  432/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9478, Loss: 0.0351
# Epoch   5 Batch  448/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9215, Loss: 0.0427
# Epoch   5 Batch  464/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9141, Loss: 0.0361
# Epoch   5 Batch  480/1077 - Train Accuracy: 0.9585, Validation Accuracy: 0.9556, Loss: 0.0357
# Epoch   5 Batch  496/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9311, Loss: 0.0381
# Epoch   5 Batch  512/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9407, Loss: 0.0253
# Epoch   5 Batch  528/1077 - Train Accuracy: 0.9262, Validation Accuracy: 0.9322, Loss: 0.0401
# Epoch   5 Batch  544/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9382, Loss: 0.0253
# Epoch   5 Batch  560/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9517, Loss: 0.0350
# Epoch   5 Batch  576/1077 - Train Accuracy: 0.9704, Validation Accuracy: 0.9439, Loss: 0.0357
# Epoch   5 Batch  592/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9524, Loss: 0.0417
# Epoch   5 Batch  608/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9542, Loss: 0.0345
# Epoch   5 Batch  624/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9460, Loss: 0.0367
# Epoch   5 Batch  640/1077 - Train Accuracy: 0.9669, Validation Accuracy: 0.9506, Loss: 0.0349
# Epoch   5 Batch  656/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9609, Loss: 0.0333
# Epoch   5 Batch  672/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9414, Loss: 0.0302
# Epoch   5 Batch  688/1077 - Train Accuracy: 0.9582, Validation Accuracy: 0.9467, Loss: 0.0250
# Epoch   5 Batch  704/1077 - Train Accuracy: 0.9313, Validation Accuracy: 0.9332, Loss: 0.0476
# Epoch   5 Batch  720/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9496, Loss: 0.0358
# Epoch   5 Batch  736/1077 - Train Accuracy: 0.9663, Validation Accuracy: 0.9442, Loss: 0.0268
# Epoch   5 Batch  752/1077 - Train Accuracy: 0.9665, Validation Accuracy: 0.9389, Loss: 0.0333
# Epoch   5 Batch  768/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9503, Loss: 0.0295
# Epoch   5 Batch  784/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9506, Loss: 0.0256
# Epoch   5 Batch  800/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9588, Loss: 0.0326
# Epoch   5 Batch  816/1077 - Train Accuracy: 0.9585, Validation Accuracy: 0.9442, Loss: 0.0364
# Epoch   5 Batch  832/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9435, Loss: 0.0282
# Epoch   5 Batch  848/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9400, Loss: 0.0359
# Epoch   5 Batch  864/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9535, Loss: 0.0455
# Epoch   5 Batch  880/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9425, Loss: 0.0319
# Epoch   5 Batch  896/1077 - Train Accuracy: 0.9498, Validation Accuracy: 0.9371, Loss: 0.0326
# Epoch   5 Batch  912/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9315, Loss: 0.0380
# Epoch   5 Batch  928/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9400, Loss: 0.0320
# Epoch   5 Batch  944/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9574, Loss: 0.0340
# Epoch   5 Batch  960/1077 - Train Accuracy: 0.9501, Validation Accuracy: 0.9439, Loss: 0.0348
# Epoch   5 Batch  976/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9336, Loss: 0.0383
# Epoch   5 Batch  992/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9442, Loss: 0.0366
# Epoch   5 Batch 1008/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9357, Loss: 0.0435
# Epoch   5 Batch 1024/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9464, Loss: 0.0490
# Epoch   5 Batch 1040/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.9428, Loss: 0.0368
# Epoch   5 Batch 1056/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9297, Loss: 0.0283
# Epoch   5 Batch 1072/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9393, Loss: 0.0343
# Epoch   6 Batch   16/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9421, Loss: 0.0357
# Epoch   6 Batch   32/1077 - Train Accuracy: 0.9304, Validation Accuracy: 0.9428, Loss: 0.0353
# Epoch   6 Batch   48/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9457, Loss: 0.0473
# Epoch   6 Batch   64/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9393, Loss: 0.0284
# Epoch   6 Batch   80/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9432, Loss: 0.0326
# Epoch   6 Batch   96/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9435, Loss: 0.0334
# Epoch   6 Batch  112/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9592, Loss: 0.0212
# Epoch   6 Batch  128/1077 - Train Accuracy: 0.9874, Validation Accuracy: 0.9290, Loss: 0.0261
# Epoch   6 Batch  144/1077 - Train Accuracy: 0.9478, Validation Accuracy: 0.9286, Loss: 0.0455
# Epoch   6 Batch  160/1077 - Train Accuracy: 0.9734, Validation Accuracy: 0.9389, Loss: 0.0234
# Epoch   6 Batch  176/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9403, Loss: 0.0288
# Epoch   6 Batch  192/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9513, Loss: 0.0366
# Epoch   6 Batch  208/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9375, Loss: 0.0327
# Epoch   6 Batch  224/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9300, Loss: 0.0463
# Epoch   6 Batch  240/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9425, Loss: 0.0337
# Epoch   6 Batch  256/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9485, Loss: 0.0497
# Epoch   6 Batch  272/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9471, Loss: 0.0540
# Epoch   6 Batch  288/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9538, Loss: 0.0455
# Epoch   6 Batch  304/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9396, Loss: 0.0394
# Epoch   6 Batch  320/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.9542, Loss: 0.0412
# Epoch   6 Batch  336/1077 - Train Accuracy: 0.9242, Validation Accuracy: 0.9290, Loss: 0.0480
# Epoch   6 Batch  352/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9357, Loss: 0.0273
# Epoch   6 Batch  368/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9528, Loss: 0.0308
# Epoch   6 Batch  384/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9482, Loss: 0.0329
# Epoch   6 Batch  400/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9432, Loss: 0.0435
# Epoch   6 Batch  416/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9439, Loss: 0.0331
# Epoch   6 Batch  432/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9425, Loss: 0.0383
# Epoch   6 Batch  448/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9411, Loss: 0.0432
# Epoch   6 Batch  464/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9286, Loss: 0.0313
# Epoch   6 Batch  480/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9638, Loss: 0.0320
# Epoch   6 Batch  496/1077 - Train Accuracy: 0.9816, Validation Accuracy: 0.9432, Loss: 0.0284
# Epoch   6 Batch  512/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9574, Loss: 0.0317
# Epoch   6 Batch  528/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9567, Loss: 0.0356
# Epoch   6 Batch  544/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9389, Loss: 0.0289
# Epoch   6 Batch  560/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.9407, Loss: 0.0356
# Epoch   6 Batch  576/1077 - Train Accuracy: 0.9655, Validation Accuracy: 0.9425, Loss: 0.0367
# Epoch   6 Batch  592/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9549, Loss: 0.0356
# Epoch   6 Batch  608/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9379, Loss: 0.0347
# Epoch   6 Batch  624/1077 - Train Accuracy: 0.9423, Validation Accuracy: 0.9521, Loss: 0.0369
# Epoch   6 Batch  640/1077 - Train Accuracy: 0.9435, Validation Accuracy: 0.9471, Loss: 0.0345
# Epoch   6 Batch  656/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9339, Loss: 0.0429
# Epoch   6 Batch  672/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9418, Loss: 0.0389
# Epoch   6 Batch  688/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9542, Loss: 0.0312
# Epoch   6 Batch  704/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9496, Loss: 0.0542
# Epoch   6 Batch  720/1077 - Train Accuracy: 0.9424, Validation Accuracy: 0.9496, Loss: 0.0345
# Epoch   6 Batch  736/1077 - Train Accuracy: 0.9527, Validation Accuracy: 0.9183, Loss: 0.0338
# Epoch   6 Batch  752/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9553, Loss: 0.0271
# Epoch   6 Batch  768/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9506, Loss: 0.0287
# Epoch   6 Batch  784/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9442, Loss: 0.0311
# Epoch   6 Batch  800/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9467, Loss: 0.0290
# Epoch   6 Batch  816/1077 - Train Accuracy: 0.9696, Validation Accuracy: 0.9350, Loss: 0.0297
# Epoch   6 Batch  832/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9439, Loss: 0.0242
# Epoch   6 Batch  848/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9411, Loss: 0.0332
# Epoch   6 Batch  864/1077 - Train Accuracy: 0.9250, Validation Accuracy: 0.9453, Loss: 0.0333
# Epoch   6 Batch  880/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9318, Loss: 0.0375
# Epoch   6 Batch  896/1077 - Train Accuracy: 0.9585, Validation Accuracy: 0.9361, Loss: 0.0416
# Epoch   6 Batch  912/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9499, Loss: 0.0393
# Epoch   6 Batch  928/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9506, Loss: 0.0358
# Epoch   6 Batch  944/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9659, Loss: 0.0331
# Epoch   6 Batch  960/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9375, Loss: 0.0357
# Epoch   6 Batch  976/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9535, Loss: 0.0297
# Epoch   6 Batch  992/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9368, Loss: 0.0472
# Epoch   6 Batch 1008/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9482, Loss: 0.0590
# Epoch   6 Batch 1024/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9556, Loss: 0.0452
# Epoch   6 Batch 1040/1077 - Train Accuracy: 0.9470, Validation Accuracy: 0.9421, Loss: 0.0382
# Epoch   6 Batch 1056/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9719, Loss: 0.0293
# Epoch   6 Batch 1072/1077 - Train Accuracy: 0.9550, Validation Accuracy: 0.9482, Loss: 0.0311
# Epoch   7 Batch   16/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9322, Loss: 0.0321
# Epoch   7 Batch   32/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9556, Loss: 0.0353
# Epoch   7 Batch   48/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9517, Loss: 0.0485
# Epoch   7 Batch   64/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9517, Loss: 0.0234
# Epoch   7 Batch   80/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9528, Loss: 0.0320
# Epoch   7 Batch   96/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9503, Loss: 0.0342
# Epoch   7 Batch  112/1077 - Train Accuracy: 0.9488, Validation Accuracy: 0.9581, Loss: 0.0256
# Epoch   7 Batch  128/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9521, Loss: 0.0327
# Epoch   7 Batch  144/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9517, Loss: 0.0417
# Epoch   7 Batch  160/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9592, Loss: 0.0267
# Epoch   7 Batch  176/1077 - Train Accuracy: 0.9441, Validation Accuracy: 0.9485, Loss: 0.0318
# Epoch   7 Batch  192/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9432, Loss: 0.0292
# Epoch   7 Batch  208/1077 - Train Accuracy: 0.9431, Validation Accuracy: 0.9336, Loss: 0.0311
# Epoch   7 Batch  224/1077 - Train Accuracy: 0.9590, Validation Accuracy: 0.9403, Loss: 0.0319
# Epoch   7 Batch  240/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9279, Loss: 0.0305
# Epoch   7 Batch  256/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9357, Loss: 0.0551
# Epoch   7 Batch  272/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9411, Loss: 0.0494
# Epoch   7 Batch  288/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9464, Loss: 0.0348
# Epoch   7 Batch  304/1077 - Train Accuracy: 0.9449, Validation Accuracy: 0.9485, Loss: 0.0332
# Epoch   7 Batch  320/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9457, Loss: 0.0337
# Epoch   7 Batch  336/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9361, Loss: 0.0448
# Epoch   7 Batch  352/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9325, Loss: 0.0302
# Epoch   7 Batch  368/1077 - Train Accuracy: 0.9496, Validation Accuracy: 0.9531, Loss: 0.0283
# Epoch   7 Batch  384/1077 - Train Accuracy: 0.9719, Validation Accuracy: 0.9460, Loss: 0.0358
# Epoch   7 Batch  400/1077 - Train Accuracy: 0.9633, Validation Accuracy: 0.9489, Loss: 0.0435
# Epoch   7 Batch  416/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9531, Loss: 0.0268
# Epoch   7 Batch  432/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9485, Loss: 0.0354
# Epoch   7 Batch  448/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9261, Loss: 0.0433
# Epoch   7 Batch  464/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9347, Loss: 0.0308
# Epoch   7 Batch  480/1077 - Train Accuracy: 0.9626, Validation Accuracy: 0.9538, Loss: 0.0292
# Epoch   7 Batch  496/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9506, Loss: 0.0362
# Epoch   7 Batch  512/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9421, Loss: 0.0296
# Epoch   7 Batch  528/1077 - Train Accuracy: 0.9004, Validation Accuracy: 0.9581, Loss: 0.0295
# Epoch   7 Batch  544/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9350, Loss: 0.0238
# Epoch   7 Batch  560/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9467, Loss: 0.0307
# Epoch   7 Batch  576/1077 - Train Accuracy: 0.9548, Validation Accuracy: 0.9336, Loss: 0.0323
# Epoch   7 Batch  592/1077 - Train Accuracy: 0.9648, Validation Accuracy: 0.9371, Loss: 0.0388
# Epoch   7 Batch  608/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9421, Loss: 0.0404
# Epoch   7 Batch  624/1077 - Train Accuracy: 0.9587, Validation Accuracy: 0.9482, Loss: 0.0405
# Epoch   7 Batch  640/1077 - Train Accuracy: 0.9394, Validation Accuracy: 0.9435, Loss: 0.0437
# Epoch   7 Batch  656/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9421, Loss: 0.0383
# Epoch   7 Batch  672/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.9318, Loss: 0.0298
# Epoch   7 Batch  688/1077 - Train Accuracy: 0.9598, Validation Accuracy: 0.9304, Loss: 0.0295
# Epoch   7 Batch  704/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9268, Loss: 0.0544
# Epoch   7 Batch  720/1077 - Train Accuracy: 0.9305, Validation Accuracy: 0.9251, Loss: 0.0352
# Epoch   7 Batch  736/1077 - Train Accuracy: 0.9556, Validation Accuracy: 0.9308, Loss: 0.0343
# Epoch   7 Batch  752/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9506, Loss: 0.0327
# Epoch   7 Batch  768/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9283, Loss: 0.0268
# Epoch   7 Batch  784/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9343, Loss: 0.0327
# Epoch   7 Batch  800/1077 - Train Accuracy: 0.9559, Validation Accuracy: 0.9503, Loss: 0.0295
# Epoch   7 Batch  816/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9354, Loss: 0.0315
# Epoch   7 Batch  832/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9531, Loss: 0.0310
# Epoch   7 Batch  848/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9535, Loss: 0.0292
# Epoch   7 Batch  864/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.9325, Loss: 0.0441
# Epoch   7 Batch  880/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9439, Loss: 0.0311
# Epoch   7 Batch  896/1077 - Train Accuracy: 0.9576, Validation Accuracy: 0.9556, Loss: 0.0482
# Epoch   7 Batch  912/1077 - Train Accuracy: 0.9680, Validation Accuracy: 0.9450, Loss: 0.0345
# Epoch   7 Batch  928/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9439, Loss: 0.0384
# Epoch   7 Batch  944/1077 - Train Accuracy: 0.9580, Validation Accuracy: 0.9347, Loss: 0.0266
# Epoch   7 Batch  960/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9549, Loss: 0.0348
# Epoch   7 Batch  976/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9528, Loss: 0.0297
# Epoch   7 Batch  992/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9442, Loss: 0.0438
# Epoch   7 Batch 1008/1077 - Train Accuracy: 0.9457, Validation Accuracy: 0.9467, Loss: 0.0395
# Epoch   7 Batch 1024/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9478, Loss: 0.0517
# Epoch   7 Batch 1040/1077 - Train Accuracy: 0.9354, Validation Accuracy: 0.9513, Loss: 0.0355
# Epoch   7 Batch 1056/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9357, Loss: 0.0342
# Epoch   7 Batch 1072/1077 - Train Accuracy: 0.9740, Validation Accuracy: 0.9489, Loss: 0.0256
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    ids = []
    for word in sentence.lower().split(' '):
        try:
            ids.append(vocab_to_int[word])
        except KeyError:
            ids.append(vocab_to_int['<UNK>'])
    return ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [175, 230, 56, 5, 89, 51, 161]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [136, 15, 105, 339, 108, 63, 131, 231, 1]
#   French Words: il a vu un vieux camion noir . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
